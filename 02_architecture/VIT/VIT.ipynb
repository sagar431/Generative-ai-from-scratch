# %% [markdown]
# # VIT

# %% [markdown]
# ![image.png](attachment:a54612ef-774e-492b-9839-e0ff3beff30c.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# 1.Images to patches
#
# 2.embedding of patches
#
# 3.[class] token
#
# 4.Postional Information
#
# 5.self_attnetion
#
# 6.Multi Head Attention
#
# 7.Multi layer perceptron
#
# 8.Layer normalization
#
# 9.transfromer encoder
#
# 10.classfication  head
#
# 11.Vision transfromer
#
# </div>

# %% [markdown]
# # 1.Images to patches
