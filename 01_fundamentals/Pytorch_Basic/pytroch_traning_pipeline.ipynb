# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# Data handling
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
import torchvision
import torchvision.transforms as T
import pandas as pd
import numpy as np
import pandas as pd
# Correct way to import modules from scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# Utility libraries
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import random

# %%
#we will build a simple neural networks
#train it on a real world dataset
#will mimic the pytroch work flow 
#will have lot of manual elements
#end result is not important

# %%
df = pd.read_csv('https://raw.githubusercontent.com/gscdit/Breast-Cancer-Detection/refs/heads/master/data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.drop(columns=['id', 'Unnamed: 32'], inplace= True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, 1:], df.iloc[:, 0], test_size=0.2)

# %% [raw]
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# %%
X_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 16         14.68         20.13           94.74      684.5          0.09867
# 489        16.69         20.20          107.10      857.6          0.07497
# 381        11.04         14.93           70.67      372.7          0.07987
# 224        13.27         17.02           84.55      546.4          0.08445
# 375        16.17         16.07          106.30      788.5          0.09880
# ..           ...           ...             ...        ...              ...
# 90         14.62         24.02           94.57      662.7          0.08974
# 207        17.01         20.26          109.70      904.3          0.08772
# 514        15.05         19.07           97.26      701.9          0.09215
# 27         18.61         20.25          122.10     1094.0          0.09440
# 343        19.68         21.68          129.90     1194.0          0.09797
#
# ...

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
# Convert DataFrame to numpy array first
X_train_np = X_train.values.astype(np.float32)
X_test_np = X_test.values.astype(np.float32)

# Convert numpy arrays to PyTorch tensors
X_train_tensor = torch.from_numpy(X_train_np)
X_test_tensor = torch.from_numpy(X_test_np)
y_train_tensor = torch.from_numpy(y_train)
y_test_tensor = torch.from_numpy(y_test)

# Verify the tensor conversion
print("Training data shape:", X_train_tensor.shape)
print("Training data type:", X_train_tensor.dtype)
print("Training labels shape:", y_train_tensor.shape)
print("Training labels type:", y_train_tensor.dtype)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 8
#       6 X_train_tensor = torch.from_numpy(X_train_np)
#       7 X_test_tensor = torch.from_numpy(X_test_np)
# ----> 8 y_train_tensor = torch.from_numpy(y_train)
#       9 y_test_tensor = torch.from_numpy(y_test)
#      11 # Verify the tensor conversion
#
# TypeError: expected np.ndarray (got Series)

# %%
y_train
# Out:
# 16     M
# 489    M
# 381    B
# 224    B
# 375    B
#       ..
# 90     B
# 207    M
# 514    M
# 27     M
# 343    M
# Name: diagnosis, Length: 455, dtype: object

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

# %%
X_train_np
# Out:
# array([[1.468e+01, 2.013e+01, 9.474e+01, ..., 1.609e-01, 3.029e-01,
#         8.216e-02],
#        [1.669e+01, 2.020e+01, 1.071e+02, ..., 8.737e-02, 4.677e-01,
#         7.623e-02],
#        [1.104e+01, 1.493e+01, 7.067e+01, ..., 6.754e-02, 3.202e-01,
#         7.287e-02],
#        ...,
#        [1.505e+01, 1.907e+01, 9.726e+01, ..., 1.120e-01, 2.282e-01,
#         6.954e-02],
#        [1.861e+01, 2.025e+01, 1.221e+02, ..., 1.490e-01, 2.341e-01,
#         7.421e-02],
#        [1.968e+01, 2.168e+01, 1.299e+02, ..., 2.255e-01, 4.045e-01,
#         7.918e-02]], dtype=float32)

# %%
X_train_tensor.shape
# Out:
# torch.Size([455, 30])

# %% [markdown]
# ## Define the model

# %%
class MySimpleNN():

  def __init__(self, X):

    self.weights = torch.rand(X.shape[1], 1, dtype=torch.float64, requires_grad=True)
    self.bias = torch.zeros(1, dtype=torch.float64, requires_grad=True)

  def forward(self, X):
    z = torch.matmul(X, self.weights) + self.bias
    y_pred = torch.sigmoid(z)
    return y_pred

  def loss_function(self, y_pred, y):
    # Clamp predictions to avoid log(0)
    epsilon = 1e-7
    y_pred = torch.clamp(y_pred, epsilon, 1 - epsilon)

    # Calculate loss
    loss = -(y_train_tensor * torch.log(y_pred) + (1 - y_train_tensor) * torch.log(1 - y_pred)).mean()
    return loss

# %% [markdown]
# ## important  Parameters

# %%
learning_rate=0.1
epochs=25

# %%
#traning pipeline

# %%
# create model
model = MySimpleNN(X_train_tensor)

# define loop
for epoch in range(epochs):

  # forward pass
  y_pred = model.forward(X_train_tensor)

  # loss calculate
  loss = model.loss_function(y_pred, y_train_tensor)

  # backward pass
  loss.backward()

  # parameters update
  with torch.no_grad():
    model.weights -= learning_rate * model.weights.grad
    model.bias -= learning_rate * model.bias.grad

  # zero gradients
  model.weights.grad.zero_()
  model.bias.grad.zero_()

  # print loss in each epoch
  print(f'Epoch: {epoch + 1}, Loss: {loss.item()}')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[82], line 8
#       4 # define loop
#       5 for epoch in range(epochs):
#       6
#       7   # forward pass
# ----> 8   y_pred = model.forward(X_train_tensor)
#      10   # loss calculate
#      11   loss = model.loss_function(y_pred, y_train_tensor)
#
# Cell In[79], line 9, in MySimpleNN.forward(self, X)
#       8 def forward(self, X):
# ----> 9   z = torch.matmul(X, self.weights) + self.bias
#      10   y_pred = torch.sigmoid(z)
#      11   return y_pred
#
# RuntimeError: expected m1 and m2 to have the same dtype, but got: float != double

# %%
model.bias
# Out:
# tensor([0.], dtype=torch.float64, requires_grad=True)
